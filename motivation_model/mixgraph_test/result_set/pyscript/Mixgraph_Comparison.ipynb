# %%
from traversal import *

import traversal as tv
import string_utils
import plotly.express as px
from log_file_handler import get_data_list, open_file

COLUMN_NUM = 4

TABLE_NAME_COMPACTION_ANALYSIS = "compaction_analysis"

def pk_list_to_columns(primary_key_list):
    data_row = ""
    
    data_row += '%s,' % primary_key_list[-4].split("_")[1]
#     print(primary_key_list[-4].split("_")[1])
    data_row += '"%s",' % primary_key_list[-3].replace("StorageMaterial.","")
    data_row += '"%s",' % primary_key_list[-2]
    data_row += '"%s",' % primary_key_list[-1]
    return data_row

def create_data_table(conn):
    c = conn.cursor()

    c.execute("Drop Table if exists "+TABLE_NAME_COMPACTION_ANALYSIS)
    c.execute("CREATE TABLE "+TABLE_NAME_COMPACTION_ANALYSIS+" (keyrange_count INT,media text, cpu text, batch_size text" +
              #   ",IOPS INT, average_latency_ms REAL" +
              ",compaction_frequency INT, overall_compaction_latency INT" +
              ",overall_compaction_cpu_latency INT" +
              ",overall_input_record INT" +
              ",overall_output_record INT" +
              ",overall_redundant_record INT" +
              ")")
    conn.commit()

    print("table created")
    
def get_row(dir_path):
    stdfile, logfile = tv.get_log_and_std_files(dir_path)
    primary_key_list = dir_path.split(os.sep)[-COLUMN_NUM:]
    data_row = pk_list_to_columns(primary_key_list)
    value_list = get_data_list(open_file(logfile))
    compaction_frequency = len(value_list[0])

    data_row += str(compaction_frequency)+","
    
    for value in value_list:
        data_row += str(sum(value))+","
    return data_row[0:-1]


dirs = get_log_dirs("./")


db_conn = sqlite3.connect('speed_info.db')

create_data_table(db_conn)

insert_sql_head = "INSERT INTO "+TABLE_NAME_COMPACTION_ANALYSIS+" VALUES"

for dir in dirs:
    sql_data_row = get_row(dir)
    sql_sentence = insert_sql_head + "(" + sql_data_row + ")"
#     print(sql_sentence)
    db_conn.execute(sql_sentence)

print("DB Loaded")
# df = pd.read_sql_query(
#     "SELECT * FROM "+TABLE_NAME_COMPACTION_ANALYSIS, db_conn)

# column_list = list(df.columns.values)[-6:]
# Out:
# table created
# DB Loaded

# %%
import pandas as pd
df = pd.read_sql_query(
    "SELECT * FROM "+TABLE_NAME_COMPACTION_ANALYSIS, db_conn)

# %%
keyranges=[15,30,60,90]
paint_dfs = []
for keyrange in keyranges:
#     print("SELECT * FROM "+TABLE_NAME_COMPACTION_ANALYSIS +" WHERE keyrange_count = '%d'"%keyrange)
    paint_df = pd.read_sql_query("SELECT * FROM "+TABLE_NAME_COMPACTION_ANALYSIS +" WHERE keyrange_count = '%d'"%keyrange, db_conn)
    paint_dfs.append(paint_df)

# %%
# print(paint_dfs[0])

# %%
df = pd.read_sql_query(
    "SELECT * FROM "+TABLE_NAME_COMPACTION_ANALYSIS, db_conn)

column_list = list(df.columns.values)[-6:]
column_list
# Out:
# ['compaction_frequency',
#  'overall_compaction_latency',
#  'overall_compaction_cpu_latency',
#  'overall_input_record',
#  'overall_output_record',
#  'overall_redundant_record']

# %%
def paint_for_one_column(column_name,paint_df):

    df = pd.read_sql_query("SELECT * FROM %s" %
                           TABLE_NAME_COMPACTION_ANALYSIS, db_conn)

    column_label = column_name.replace("_", " ")
    column_label = column_label.replace("overall", "cumulative")
    column_label = column_label.replace("latency", "latency (ms)")

    fig = px.bar(df, x="cpu", y=column_name, color="keyrange_count", barmode="group",
                 facet_col="media",
#                  facet_row="batch_size",
                 category_orders={
                     "media": ["SATASSD", "SATAHDD", "NVMeSSD","PM"],
                     "cpu": [str(x)+"CPU" for x in [8,16,32]],
                     "batch_size":[str(x)+"MB" for x in range(64,128)]
                     #  "media": sorted_media,
                     #  "media1_size":["1GB","5GB","10GB"]
                 },
                 labels={"media": "Storage Media",
                         "workload_size": "Estimate Input Size",
                         "IOPS": "OPs/sec","cpu":"",
                         "batch_size":"Operation Batch Size"},
                 #  color_discrete_map=batch_size_to_color_map
                 )
    fontsize = 20

    fig.update_layout(
        autosize=False,
        width=1600,
        height=900,
        font=dict(size=fontsize),
        # plot_bgcolor='white',
    )
    fig.update_yaxes(automargin=True)
    fig.update_xaxes(showgrid=False)
    fig.show()
#     fig_name = "../image/%s.pdf" % column_name
#     print("plotting fig %s finished" % fig_name)
#     fig.write_image(fig_name)
for paint_df in paint_dfs:
    for column in column_list:
        paint_for_one_column(column,paint_df)
# Out:
# <div>
#
#
#             <div id="6a3eb460-e59b-4baf-b723-7b93fcfcccf1" class="plotly-graph-div" style="height:900px; width:1600px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("6a3eb460-e59b-4baf-b723-7b93fcfcccf1")) {
#                     Plotly.newPlot(
#                         '6a3eb460-e59b-4baf-b723-7b93fcfcccf1',
#                         [{"alignmentgroup": "True", "hovertemplate": "Storage Media=SATASSD<br>=%{x}<br>compaction_frequency=%{y}<br>keyrange_count=%{marker.color}<extra></extra>", "legendgroup": "", "marker": {"color": [15, 15, 15, 15, 15, 15, 30, 30, 30, 30, 30, 30, 60, 60, 60, 60, 60, 60, 90, 90, 90, 90, 90, 90], "coloraxis": "coloraxis"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["16CPU", "16CPU", "32CPU", "32CPU", "8CPU", "8CPU", "16CPU", "16CPU", "32CPU", "32CPU", "8CPU", "8CPU", "16CPU", "16CPU", "32CPU", "32CPU", "8CPU", "8CPU", "16CPU", "16CPU", "32CPU", "32CPU", "8CPU", "8CPU"], "xaxis": "x", "y": [343, 753, 368, 745, 362, 752, 643, 1338, 649, 1330, 628, 1303, 364, 746, 359, 755, 356, 745, 358, 754, 352, 740, 349, 745], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Storage Media=SATAHDD<br>=%{x}<br>compaction_frequency=%{y}<br>keyrange_count=%{marker.color}<extra></extra>", "legendgroup": "", "marker": {"color": [15, 15, 15, 15, 15, 15, 30, 30, 30, 30, 30, 30, 60, 60, 60, 60, 60, 60, 90, 90, 90, 90, 90, 90], "coloraxis": "coloraxis"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["16CPU", "16CPU", "32CPU", "32CPU", "8CPU", "8CPU", "16CPU", "16CPU", "32CPU", "32CPU", "8CPU", "8CPU", "16CPU", "16CPU", "32CPU", "32CPU", "8CPU", "8CPU", "16CPU", "16CPU", "32CPU", "32CPU", "8CPU", "8CPU"], "xaxis": "x2", "y": [363, 749, 357, 745, 357, 741, 596, 1309, 630, 1308, 507, 1268, 349, 721, 349, 743, 341, 731, 346, 734, 356, 743, 356, 750], "yaxis": "y2"}, {"alignmentgroup": "True", "hovertemplate": "Storage Media=NVMeSSD<br>=%{x}<br>compaction_frequency=%{y}<br>keyrange_count=%{marker.color}<extra></extra>", "legendgroup": "", "marker": {"color": [15, 15, 15, 15, 15, 15, 30, 30, 30, 30, 30, 30, 60, 60, 60, 60, 60, 60, 90, 90, 90, 90, 90, 90], "coloraxis": "coloraxis"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["16CPU", "16CPU", "32CPU", "32CPU", "8CPU", "8CPU", "16CPU", "16CPU", "32CPU", "32CPU", "8CPU", "8CPU", "16CPU", "16CPU", "32CPU", "32CPU", "8CPU", "8CPU", "16CPU", "16CPU", "32CPU", "32CPU", "8CPU", "8CPU"], "xaxis": "x3", "y": [383, 765, 386, 746, 387, 748, 692, 1309, 685, 1324, 687, 1318, 395, 762, 395, 769, 396, 762, 387, 768, 389, 764, 386, 776], "yaxis": "y3"}, {"alignmentgroup": "True", "hovertemplate": "Storage Media=PM<br>=%{x}<br>compaction_frequency=%{y}<br>keyrange_count=%{marker.color}<extra></extra>", "legendgroup": "", "marker": {"color": [15, 15, 15, 15, 15, 15, 30, 30, 30, 30, 30, 30, 60, 60, 60, 60, 60, 60, 90, 90, 90, 90, 90, 90], "coloraxis": "coloraxis"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["16CPU", "16CPU", "32CPU", "32CPU", "8CPU", "8CPU", "16CPU", "16CPU", "32CPU", "32CPU", "8CPU", "8CPU", "16CPU", "16CPU", "32CPU", "32CPU", "8CPU", "8CPU", "16CPU", "16CPU", "32CPU", "32CPU", "8CPU", "8CPU"], "xaxis": "x4", "y": [345, 751, 357, 748, 347, 743, 652, 1335, 656, 1333, 652, 1298, 363, 737, 372, 730, 361, 741, 368, 742, 373, 759, 363, 747], "yaxis": "y4"}],
#                         {"annotations": [{"font": {}, "showarrow": false, "text": "Storage Media=SATASSD", "x": 0.1175, "xanchor": "center", "xref": "paper", "y": 1.0, "yanchor": "bottom", "yref": "paper"}, {"font": {}, "showarrow": false, "text": "Storage Media=SATAHDD", "x": 0.3725, "xanchor": "center", "xref": "paper", "y": 1.0, "yanchor": "bottom", "yref": "paper"}, {"font": {}, "showarrow": false, "text": "Storage Media=NVMeSSD", "x": 0.6275, "xanchor": "center", "xref": "paper", "y": 1.0, "yanchor": "bottom", "yref": "paper"}, {"font": {}, "showarrow": false, "text": "Storage Media=PM", "x": 0.8824999999999998, "xanchor": "center", "xref": "paper", "y": 1.0, "yanchor": "bottom", "yref": "paper"}], "autosize": false, "barmode": "group", "coloraxis": {"colorbar": {"title": {"text": "keyrange_count"}}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]]}, "font": {"size": 20}, "height": 900, "legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0 ...
# <div>
#
#
#             <div id="7eb7e8ee-e65d-497f-92d6-892bb75acdf6" class="plotly-graph-div" style="height:900px; width:1600px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("7eb7e8ee-e65d-497f-92d6-892bb75acdf6")) {
#                     Plotly.newPlot(
#                         '7eb7e8ee-e65d-497f-92d6-892bb75acdf6',
#                         [{"alignmentgroup": "True", "hovertemplate": "Storage Media=SATASSD<br>=%{x}<br>overall_compaction_latency=%{y}<br>keyrange_count=%{marker.color}<extra></extra>", "legendgroup": "", "marker": {"color": [15, 15, 15, 15, 15, 15, 30, 30, 30, 30, 30, 30, 60, 60, 60, 60, 60, 60, 90, 90, 90, 90, 90, 90], "coloraxis": "coloraxis"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["16CPU", "16CPU", "32CPU", "32CPU", "8CPU", "8CPU", "16CPU", "16CPU", "32CPU", "32CPU", "8CPU", "8CPU", "16CPU", "16CPU", "32CPU", "32CPU", "8CPU", "8CPU", "16CPU", "16CPU", "32CPU", "32CPU", "8CPU", "8CPU"], "xaxis": "x", "y": [2367676268, 5812055507, 3085906679, 5520312194, 3240652656, 5721609964, 5079722310, 9980319494, 6330339340, 13464671362, 5180661302, 5875778322, 2145680253, 3517132558, 2717561387, 4321200687, 1958294602, 2800919532, 3305379269, 5771158964, 3186551084, 5375486983, 3157668237, 4763721548], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Storage Media=SATAHDD<br>=%{x}<br>overall_compaction_latency=%{y}<br>keyrange_count=%{marker.color}<extra></extra>", "legendgroup": "", "marker": {"color": [15, 15, 15, 15, 15, 15, 30, 30, 30, 30, 30, 30, 60, 60, 60, 60, 60, 60, 90, 90, 90, 90, 90, 90], "coloraxis": "coloraxis"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["16CPU", "16CPU", "32CPU", "32CPU", "8CPU", "8CPU", "16CPU", "16CPU", "32CPU", "32CPU", "8CPU", "8CPU", "16CPU", "16CPU", "32CPU", "32CPU", "8CPU", "8CPU", "16CPU", "16CPU", "32CPU", "32CPU", "8CPU", "8CPU"], "xaxis": "x2", "y": [5144934411, 7874567101, 5725482848, 8159332234, 4856484587, 9842129391, 15750909678, 22873028438, 14376963198, 27315052051, 11971837063, 14116079461, 5295522615, 6225241324, 5971250211, 9532678554, 4267006826, 5819931593, 6941689518, 9176179799, 7869451777, 11794435933, 4753234174, 7599584575], "yaxis": "y2"}, {"alignmentgroup": "True", "hovertemplate": "Storage Media=NVMeSSD<br>=%{x}<br>overall_compaction_latency=%{y}<br>keyrange_count=%{marker.color}<extra></extra>", "legendgroup": "", "marker": {"color": [15, 15, 15, 15, 15, 15, 30, 30, 30, 30, 30, 30, 60, 60, 60, 60, 60, 60, 90, 90, 90, 90, 90, 90], "coloraxis": "coloraxis"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["16CPU", "16CPU", "32CPU", "32CPU", "8CPU", "8CPU", "16CPU", "16CPU", "32CPU", "32CPU", "8CPU", "8CPU", "16CPU", "16CPU", "32CPU", "32CPU", "8CPU", "8CPU", "16CPU", "16CPU", "32CPU", "32CPU", "8CPU", "8CPU"], "xaxis": "x3", "y": [1276747930, 1944917843, 1282695914, 1930263638, 1268634578, 1854774651, 2273342584, 2503597547, 2520477609, 3020082820, 1827168332, 2329940015, 1168296823, 1314820299, 1220030956, 1439695721, 1160379238, 1305105489, 1264830610, 1778602755, 1294475642, 1844533525, 1248834852, 1662599833], "yaxis": "y3"}, {"alignmentgroup": "True", "hovertemplate": "Storage Media=PM<br>=%{x}<br

#                         [{"alignmentgroup": "True", "hovertemplate": "Storage Media=SATASSD<br>=%{x}<br>overall_output_record=%{y}<br>keyrange_count=%{marker.color}<extra></extra>", "legendgroup": "", "marker": {"color": [15, 15, 15, 15, 15, 15, 30, 30, 30, 30, 30, 30, 60, 60, 60, 60, 60, 60, 90, 90, 90, 90, 90, 90], "coloraxis": "coloraxis"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["16CPU", "16CPU", "32CPU", "32CPU", "8CPU", "8CPU", "16CPU", "16CPU", "32CPU", "32CPU", "8CPU", "8CPU", "16CPU", "16CPU", "32CPU", "32CPU", "8CPU", "8CPU", "16CPU", "16CPU", "32CPU", "32CPU", "8CPU", "8CPU"], "xaxis": "x", "y": [3442430301, 3836731486, 3628840838, 3871830996, 3540736743, 3808058338, 4011505436, 4322924574, 3961245287, 4267726536, 3976533305, 4495643571, 3746871111, 4117921183, 3671927013, 4034553992, 3708968150, 4106724988, 3620309018, 3900669507, 3559008202, 3947182658, 3430117019, 3971952909], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Storage Media=SATAHDD<br>=%{x}<br>overall_output_record=%{y}<br>keyrange_count=%{marker.color}<extra></extra>", "legendgroup": "", "marker": {"color": [15, 15, 15, 15, 15, 15, 30, 30, 30, 30, 30, 30, 60, 60, 60, 60, 60, 60, 90, 90, 90, 90, 90, 90], "coloraxis": "coloraxis"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["16CPU", "16CPU", "32CPU", "32CPU", "8CPU", "8CPU", "16CPU", "16CPU", "32CPU", "32CPU", "8CPU", "8CPU", "16CPU", "16CPU", "32CPU", "32CPU", "8CPU", "8CPU", "16CPU", "16CPU", "32CPU", "32CPU", "8CPU", "8CPU"], "xaxis": "x2", "y": [3191883982, 3695919240, 3174318137, 3658065703, 3241610430, 3587767798, 3523032621, 4196300730, 3565442479, 4120468837, 3059423325, 3875103078, 2999168986, 3502137510, 3032584148, 3549105661, 3247266001, 3535087923, 3166592550, 3603326097, 3011440317, 3552789470, 3105343706, 3658929156], "yaxis": "y2"}, {"alignmentgroup": "True", "hovertemplate": "Storage Media=NVMeSSD<br>=%{x}<br>overall_output_record=%{y}<br>keyrange_count=%{marker.color}<extra></extra>", "legendgroup": "", "marker": {"color": [15, 15, 15, 15, 15, 15, 30, 30, 30, 30, 30, 30, 60, 60, 60, 60, 60, 60, 90, 90, 90, 90, 90, 90], "coloraxis": "coloraxis"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["16CPU", "16CPU", "32CPU", "32CPU", "8CPU", "8CPU", "16CPU", "16CPU", "32CPU", "32CPU", "8CPU", "8CPU", "16CPU", "16CPU", "32CPU", "32CPU", "8CPU", "8CPU", "16CPU", "16CPU", "32CPU", "32CPU", "8CPU", "8CPU"], "xaxis": "x3", "y": [4041409455, 4594334299, 4074071313, 4502719650, 4052929438, 4555041892, 4624005763, 4827190999, 4651209994, 4760292769, 4595627231, 4898027383, 4206049377, 4615235309, 4201839062, 4644396655, 4206895444, 4616103521, 4138720833, 4572314655, 4124897204, 4550327853, 4105746730, 4667266759], "yaxis": "y3"}, {"alignmentgroup": "True", "hovertemplate": "Storage Media=PM<br>=%{x}<br>overall_output_record=%{y}<br>keyrange_count=%{marker.color}<extra></extra>", "legendgroup": "", "marker": {"color": [15, 15, 15, 15, 15, 15, 30, 30, 30, 30, 30, 30, 60, 60, 60, 60, 60, 60, 90, 90, 90, 90, 90, 90], "coloraxis": "coloraxis"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["16CPU", "16CPU", "32CPU", "32CPU", "8CPU", "8CPU", "16CPU", "16CPU", "32CPU", "32CPU", "8CPU", "8CPU", "16CPU", "16CPU", "32CPU", "32CPU", "8CPU", "8CPU", "16CPU", "16CPU", "32CPU", "32CPU", "8CPU", "8CPU"], "xaxis": "x4", "y": [3603706280, 3887828209, 3662369974, 3808300035, 3604424885, 3870447662, 3891794682, 4227699467, 3880965947, 4200251467, 3914896301, 4349529000, 3794780763, 4279929407, 3875564652, 4262136824, 3810152286, 4264871549, 3779322500, 4053084569, 3782451548, 3920908444, 3744370648, 4148658233], "yaxis": "y4"}],
#                         {"annotations": [{"font": {}, "showarrow": false, "text": "Storage Media=SATASSD", "x": 0.1175, "xanchor": "center", "xref": "paper", "y": 1.0, "yanchor": "bottom", "yref": "paper"}, {"font": {}, "showarrow": false, "text": "Storage Media=SATAHDD", "x": 0.3725, "xanchor": "center", "xref": "paper", "y": 1.0, "yanchor": "bottom", "yref": "paper"}, {"font": {}, "showarrow": false, "text": "Storage Media=NVMeSSD", "x": 0.6275, "xanchor": "center", "xref": "paper", "y": 1.0, "yanchor": "bottom", "yref": "paper"}, {"font": {}, "showarrow": false, "text": "Storage Media=PM", "x": 0.8824999999999998, "xanchor": "center", "xref": "paper", "y": 1.0, "yanchor": "bottom", "yref": "paper"}], "autosize": false, "barmode": "group", "coloraxis": {"colorbar": {"title": {"text": "keyrange_count"}}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]]}, "font": {"size": 20}, "height": 900, "legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777
# <div>
#
#
#             <div id="b68acf5b-000c-4dc1-94d4-fa12263479e3" class="plotly-graph-div" style="height:900px; width:1600px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("b68acf5b-000c-4dc1-94d4-fa12263479e3")) {
#                     Plotly.newPlot(
#                         'b68acf5b-000c-4dc1-94d4-fa12263479e3',
#                         [{"alignmentgroup": "True", "hovertemplate": "Storage Media=SATASSD<br>=%{x}<br>overall_redundant_record=%{y}<br>keyrange_count=%{marker.color}<extra></extra>", "legendgroup": "", "marker": {"color": [15, 15, 15, 15, 15, 15, 30, 30, 30, 30, 30, 30, 60, 60, 60, 60, 60, 60, 90, 90, 90, 90, 90, 90], "coloraxis": "coloraxis"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["16CPU", "16CPU", "32CPU", "32CPU", "8CPU", "8CPU", "16CPU", "16CPU", "32CPU", "32CPU", "8CPU", "8CPU", "16CPU", "16CPU", "32CPU", "32CPU", "8CPU", "8CPU", "16CPU", "16CPU", "32CPU", "32CPU", "8CPU", "8CPU"], "xaxis": "x", "y": [140839543, 156561744, 144402732, 144213260, 139421477, 143371240, 152453838, 171431517, 190505040, 159067758, 165053623, 160707378, 142131548, 168602925, 131166659, 185354612, 137287203, 171823399, 148566728, 148555194, 139287598, 147280122, 152462879, 143676714], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Storage Media=SATAHDD<br>=%{x}<br>overall_redundant_record=%{y}<br>keyrange_count=%{marker.color}<extra></extra>", "legendgroup": "", "marker": {"color": [15, 15, 15, 15, 15, 15, 30, 30, 30, 30, 30, 30, 60, 60, 60, 60, 60, 60, 90, 90, 90, 90, 90, 90], "coloraxis": "coloraxis"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["16CPU", "16CPU", "32CPU", "32CPU", "8CPU", "8CPU", "16CPU", "16CPU", "32CPU", "32CPU", "8CPU", "8CPU", "16CPU", "16CPU", "32CPU", "32CPU", "8CPU", "8CPU", "16CPU", "16CPU", "32CPU", "32CPU", "8CPU", "8CPU"], "xaxis": "x2", "y": [194534349, 149699894, 148904533, 170923362, 169444389, 142879776, 166576183, 167540453, 180492461, 165564804, 154124844, 153682494, 177887975, 139451314, 193348264, 160052596, 142287577, 136081814, 145555185, 139101449, 176584987, 141986484, 186531033, 196392348], "yaxis": "y2"}, {"alignmentgroup": "True", "hovertemplate": "Storage Media=NVMeSSD<br>=%{x}<br>overall_redundant_record=%{y}<br>keyrange_count=%{marker.color}<extra></extra>", "legendgroup": "", "marker": {"color": [15, 15, 15, 15, 15, 15, 30, 30, 30, 30, 30, 30, 60, 60, 60, 60, 60, 60, 90, 90, 90, 90, 90, 90], "coloraxis": "coloraxis"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["16CPU", "16CPU", "32CPU", "32CPU", "8CPU", "8CPU", "16CPU", "16CPU", "32CPU", "32CPU", "8CPU", "8CPU", "16CPU", "16CPU", "32CPU", "32CPU", "8CPU", "8CPU", "16CPU", "16CPU", "32CPU", "32CPU", "8CPU", "8CPU"], "xaxis": "x3", "y": [138786158, 155613207, 142791040, 143103089, 145672606, 144287702, 155920831, 164103496, 161188385, 166524514, 153623431, 158419439, 151413714, 145528764, 147537068, 152721194, 151282366, 144286838, 144075866, 145878425, 144196286, 143864895, 141018775, 151838475], "yaxis": "y3"}, {"alignmentgroup": "True", "hovertemplate": "Storage Media=PM<br>=%{x}<br>overall_redundant_record=%{y}<br>keyrange_count=%{marker.color}<extra></extra>", "legendgroup": "", "marker": {"color": [15, 15, 15, 15, 15, 15, 30, 30, 30, 30, 30, 30, 60, 60, 60, 60, 60, 60, 90, 90, 90, 90, 90, 90], "coloraxis": "coloraxis"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["16CPU", "16CPU", "32CPU", "32CPU", "8CPU", "8CPU", "16CPU", "16CPU", "32CPU", "32CPU", "8CPU", "8CPU", "16CPU", "16CPU", "32CPU", "32CPU", "8CPU", "8CPU", "16CPU", "16CPU", "32CPU", "32CPU", "8CPU", "8CPU"], "xaxis": "x4", "y": [138227266, 170179957, 180974852, 143607621, 147855850, 142317056, 173103755, 191324498, 163406834, 158195660, 176735118, 159311487, 139777619, 148799812, 152261280, 153092221, 131764591, 154721347, 147657355, 145452675, 169256749, 185033609, 145361617, 145855376], "yaxis": "y4"}],
#                         {"annotations": [{"font": {}, "showarrow": false, "text": "Storage Media=SATASSD", "x": 0.1175, "xanchor": "center", "xref": "paper", "y": 1.0, "yanchor": "bottom", "yref": "paper"}, {"font": {}, "showarrow": false, "text": "Storage Media=SATAHDD", "x": 0.3725, "xanchor": "center", "xref": "paper", "y": 1.0, "yanchor": "bottom", "yref": "paper"}, {"font": {}, "showarrow": false, "text": "Storage Media=NVMeSSD", "x": 0.6275, "xanchor": "center", "xref": "paper", "y": 1.0, "yanchor": "bottom", "yref": "paper"}, {"font": {}, "showarrow": false, "text": "Storage Media=PM", "x": 0.8824999999999998, "xanchor": "center", "xref": "paper", "y": 1.0, "yanchor": "bottom", "yref": "paper"}], "autosize": false, "barmode": "group", "coloraxis": {"colorbar": {"title": {"text": "keyrange_count"}}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]]}, "font": {"size": 20}, "height": 900, "legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histog
